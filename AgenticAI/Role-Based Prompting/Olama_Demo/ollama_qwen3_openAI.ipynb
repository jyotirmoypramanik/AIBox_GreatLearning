# %%
from openai import OpenAI

client = OpenAI(
    base_url="http://localhost:11434/v1",  # ← note the /v1 suffix
    api_key="ollama",                       # ← any non-empty string works
)

response = client.chat.completions.create(
    model="qwen3:4b",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user",   "content": "Explain what an API is in 2 sentences."},
    ]
)

print(response.choices[0].message.content)
# Out:
# An API (Application Programming Interface) is a set of defined rules, protocols, and tools that enables different software applications to communicate and interact with each other. For instance, when you use a weather app to check the forecast, it sends requests through an API to a weather service provider to retrieve real-time data securely and efficiently.
